# %%
import pytesseract

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
OrImg=cv2.imread('test2.png')

# %%
plt.imshow(OrImg)

# %%
img2char=pytesseract.image_to_string(OrImg)
print(img2char)
# Out:
# A Simple PDF File
#
# This is a small demonstration .pdf file -
#
# just for use in the Virtual Mechanics tutorials. More text. And more
# text. And more text. And more text. And more text.
#
# And more text. And more text. And more text. And more text. And more
# text. And more text. Boring, zzzzz. And more text. And more text. And
# more text. And more text. And more text. And more text. And more text.
# And more text. And more text.
#
# And more text. And more text. And more text. And more text. And more
# text. And more text. And more text. Even more. Continued on page 2 ...

# %%
img2box=pytesseract.image_to_boxes(OrImg)
print(img2box)
# Out:
# A 22 310 52 342 0
# S 66 310 93 343 0
# i 97 310 102 342 0
# m 107 310 140 334 0
# p 134 301 156 343 0
# l 145 301 175 342 0
# e 179 310 201 334 0
# P 218 310 243 342 0
# D 248 310 276 342 0
# F 281 310 303 342 0
# F 321 310 327 342 0
# i 321 310 343 342 0
# l 348 310 362 342 0
# e 366 310 389 334 0
# T 34 254 44 266 0
# h 40 254 46 266 0
# i 45 254 53 266 0
# s 54 254 65 266 0
# i 71 254 73 266 0
# s 74 254 82 263 0
# a 87 254 96 263 0
# s 101 254 109 263 0
# m 110 254 122 263 0
# a 120 254 126 266 0
# l 123 254 132 263 0
# l 133 254 139 266 0
# d 144 254 153 266 0
# e 154 254 163 263 0
# m 164 254 176 263 0
# o 172 254 180 266 0
# n 177 254 186 263 0
# s 187 254 195 263 0
# t 196 254 203 263 0
# r 204 254 214 266 0
# a 212 254 218 266 0
# t 214 254 223 263 0
# i 223 254 240 266 0
# o 232 254 238 266 0
# n 241 254 249 263 0
# . 256 254 258 256 0
# p 260 250 268 263 0
# d 266 250 272 266 0
# f 269 254 284 266 0
# f 287 254 290 266 0
# i 287 254 295 266 0
# l 296 254 298 266 0
# ...

# %%
imgH, imgW, imgC = OrImg.shape

# %%
for box in img2box.splitlines():
    box=box.split(' ')
    x,y,w,h=int(box[1]),int(box[2]),int(box[3]),int(box[4])
    cv2.rectangle(OrImg, (x,imgH-y), (w,imgH-h), (255,0,0),1)

# %%
plt.imshow(OrImg)

# %%
cv2.imwrite('test.png', image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Rajni\Desktop\Python\imageto text\ImgRec1.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rajni/Desktop/Python/imageto%20text/ImgRec1.ipynb#ch0000012?line=0'>1</a> cv2.imwrite('test.png', image)
#
# NameError: name 'image' is not defined

# %%
#import numpy as np
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN

cap = cv2.VideoCapture("RAJ.mkv")
#cap. set (cv2. CAP_PROP_FPS, 170)
# Check if the is webcam is opened correctly
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
cntr =0;

while True:
    ret, frame = cap.read( )
    entr= cntr+1;
    if ((cntr%20)==0):
        imgH, imgw,_ = frame.shape
        #eye_cascade = cv2. CascadeClassifier(cv2. data. haarcascades +'haarcascade_eye. xml' )

        X1, y1, w1,h1 = 0,0, imgH, imgw
        imgchar = pytesseract.image_to_string(frame)
        imgboxes = pytesseract.image_to_boxes(frame)
        for boxes in imgboxes.splitlines( ) :
            boxes= boxes.split(' ')
            x,y,w,h= int(boxes[1]), int(boxes[2]), int(boxes[3]), int(boxes[4])
            cv2.rectangle(frame, (x, imgH-y), (w, imgH-h), (255, 0, 0),3)

            #cv2. rectangle(frame, (x1, x1), (x1 + wi, yl + h1), (e,e,8), -1)
            cv2.putText(frame, imgchar, (X1 + int(w1/50), y1 + int(h1/50) ), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 0), 2)
            font = cv2.FONT_HERSHEY_SIMPLEX
            cv2.imshow('Text Detection Tutorial',frame)
            if cv2.waitKey(2) & 0xFF == ord('q'):
                break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Rajni\Desktop\Python\imageto text\ImgRec1.ipynb Cell 13' in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Rajni/Desktop/Python/imageto%20text/ImgRec1.ipynb#ch0000011?line=18'>19</a> #eye_cascade = cv2. CascadeClassifier(cv2. data. haarcascades +'haarcascade_eye. xml' )
#      <a href='vscode-notebook-cell:/c%3A/Users/Rajni/Desktop/Python/imageto%20text/ImgRec1.ipynb#ch0000011?line=20'>21</a> X1, y1, w1,h1 = 0,0, imgH, imgw
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Rajni/Desktop/Python/imageto%20text/ImgRec1.ipynb#ch0000011?line=21'>22</a> imgchar = pytesseract.image_to_string(frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/Rajni/Desktop/Python/imageto%20text/ImgRec1.ipynb#ch0000011?line=22'>23</a> imgboxes = pytesseract.image_to_boxes(frame)
# ...
